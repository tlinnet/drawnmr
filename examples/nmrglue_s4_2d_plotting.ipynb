# %%
from drawnmr import draw
import nmrglue as ng
import bokeh.plotting as bplt

# Get data
import os, os.path
ng_dir = 'nmrglue_data/s4_2d_plotting'
if not os.path.exists(ng_dir):
    print("No %s. Downloading."%ng_dir)
    import urllib.request, zipfile
    zipf = 'jbnmr_s4_2d_plotting.zip'
    urllib.request.urlretrieve('https://storage.googleapis.com/google-code-archive-downloads/v2/code.google.com/nmrglue/%s'%zipf, zipf)
    with zipfile.ZipFile(zipf,"r") as zip_ref:
        zip_ref.extractall("nmrglue_data")
    os.remove(zipf)

# Specify data
ng_ft2 = 'nmrglue_data/s4_2d_plotting/test.ft2'

# read in data
ng_dic, ng_data = ng.pipe.read(ng_ft2)

# Pass to figure class
fig2d = draw.fig2d(ng_dic, ng_data)
# Get the boheh figure
fig = fig2d.get_fig()

# Get output. Either to Jupyter notebook or html file 
if fig2d.isnotebook():
    from bokeh.io import output_notebook
    output_notebook()
    bplt.show(fig)
else:
    # Save to html
    filename = "nmrglue_s4_2d_plotting.html"
    bplt.output_file(filename)
    bplt.save(fig)
    # And auto open
    import webbrowser, os
    webbrowser.open('file://' + os.path.realpath(filename))
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="85581fe1-0b5a-4c23-b809-81954cca0899">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c47ab915-c52e-40d8-8e19-2249ffec56bb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("c47ab915-c52e-40d8-8e19-2249ffec56bb");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c47ab915-c52e-40d8-8e19-2249ffec56bb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c47ab915-c52e-40d8-8e19-2249ffec56bb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bd326ec0-9c6f-485e-9b00-0e53649050de":{"roots":{"references":[{"attributes":{"plot":{"id":"87acd2a0-283e-44a3-b2ca-5f779fa28834","subtype":"Figure","type":"Plot"},"ticker":{"id":"77e11cb9-1058-4f5e-8904-406356fdcb84","type":"BasicTicker"}},"id":"704794f6-5840-4e73-9e97-fb2ed6467627","type":"Grid"},{"attributes":{},"id":"25ec465e-9d69-4570-9de2-4c888f14034d","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"25ec465e-9d69-4570-9de2-4c888f14034d","type":"BasicTickFormatter"},"plot":{"id":"87acd2a0-283e-44a3-b2ca-5f779fa28834","subtype":"Figure","type":"Plot"},"ticker":{"id":"24e095f4-33ea-4c2a-9700-1c1c9f2d0140","type":"BasicTicker"}},"id":"1230f7e7-eb3c-4421-bf5e-11bc2070818d","type":"LinearAxis"},{"attributes":{"callback":null,"end":95.5,"start":139.5},"id":"e283f44f-eb04-4f53-8900-8f1914d78f7c","type":"Range1d"},{"attributes":{},"id":"24e095f4-33ea-4c2a-9700-1c1c9f2d0140","type":"BasicTicker"},{"attributes":{"below":[{"id":"493de12e-01a7-4f76-b96e-96dde3e3f9af","type":"LinearAxis"}],"left":[{"id":"1230f7e7-eb3c-4421-bf5e-11bc2070818d","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"493de12e-01a7-4f76-b96e-96dde3e3f9af","type":"LinearAxis"},{"id":"704794f6-5840-4e73-9e97-fb2ed6467627","type":"Grid"},{"id":"1230f7e7-eb3c-4421-bf5e-11bc2070818d","type":"LinearAxis"},{"id":"0c175315-2f1b-4cf3-8cf1-4eaa30e9ed10","type":"Grid"},{"id":"0aa69d2b-35b3-47c0-9fbd-f1773fe1ed28","type":"BoxAnnotation"},{"id":"9f5e9ab2-428b-43c6-a0e8-ee43702d820b","type":"GlyphRenderer"}],"title":{"id":"8dfb0b6c-010e-4ac8-9e43-b813ebdb9a43","type":"Title"},"toolbar":{"id":"2f5dfcb6-b4ff-4c2e-a8bc-663d3723035b","type":"Toolbar"},"x_range":{"id":"2f49d55e-bdf6-4b7f-83dd-108f5638cb81","type":"Range1d"},"x_scale":{"id":"8b628e1f-5337-4bb6-8438-471dfbdb97ec","type":"LinearScale"},"y_range":{"id":"e283f44f-eb04-4f53-8900-8f1914d78f7c","type":"Range1d"},"y_scale":{"id":"3cab1912-247b-42f0-ae7c-fe523d2b1fd6","type":"LinearScale"}},"id":"87acd2a0-283e-44a3-b2ca-5f779fa28834","subtype":"Figure","type":"Plot"},{"attributes":{"dimension":1,"plot":{"id":"87acd2a0-283e-44a3-b2ca-5f779fa28834","subtype":"Figure","type":"Plot"},"ticker":{"id":"24e095f4-33ea-4c2a-9700-1c1c9f2d0140","type":"BasicTicker"}},"id":"0c175315-2f1b-4cf3-8cf1-4eaa30e9ed10","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"0aa69d2b-35b3-47c0-9fbd-f1773fe1ed28","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"bd5d4f19-c58f-4b18-b53d-380d7b966836","type":"PanTool"},{"id":"b8156c35-d744-4902-bb41-4df43fa28163","type":"WheelZoomTool"},{"id":"aea4cd33-3009-493d-9cc5-459faa020b72","type":"BoxZoomTool"},{"id":"85c802c8-bbf5-4bc6-8482-811978ef6c43","type":"SaveTool"},{"id":"7d3da72c-b05d-4983-a5d1-14608f34f008","type":"ResetTool"},{"id":"cb4c79b1-60dd-4149-9704-b0c90525f4d3","type":"HelpTool"}]},"id":"2f5dfcb6-b4ff-4c2e-a8bc-663d3723035b","type":"Toolbar"},{"attributes":{},"id":"3cab1912-247b-42f0-ae7c-fe523d2b1fd6","type":"LinearScale"},{"attributes":{"formatter":{"id":"02a259e8-795d-4b70-b879-7307702cb7dc","type":"BasicTickFormatter"},"plot":{"id":"87acd2a0-283e-44a3-b2ca-5f779fa28834","subtype":"Figure","type":"Plot"},"ticker":{"id":"77e11cb9-1058-4f5e-8904-406356fdcb84","type":"BasicTicker"}},"id":"493de12e-01a7-4f76-b96e-96dde3e3f9af","type":"LinearAxis"},{"attributes":{},"id":"77e11cb9-1058-4f5e-8904-406356fdcb84","type":"BasicTicker"},{"attributes":{},"id":"02a259e8-795d-4b70-b879-7307702cb7dc","type":"BasicTickFormatter"},{"attributes":{},"id":"bd5d4f19-c58f-4b18-b53d-380d7b966836","type":"PanTool"},{"attributes":{"data_source":{"id":"c3703b54-8fab-4a65 ...
